# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace(0, 100, 1000)
y = np.sin(x)
z = np.cos(x)
#print x
df = pd.DataFrame({'x': x, 'y': y, 'z': z})
df.plot(x='x', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0bf371b90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff0bf422950>], dtype=object)
